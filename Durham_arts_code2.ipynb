# %% [markdown]
# # Durham Arts and Culture Venues
# ## 1. Data Collection
# ## 2. Creating the Map

# %%
#!pip install geopandas
# !pip install geopy
import requests
from geopy.geocoders import Nominatim

import types
import pandas as pd

import numpy as np
# !pip install folium
import folium
import csv
from pandas import json_normalize #transform json file into a dataframe

print('imports done')
# Out:
# Requirement already satisfied: geopy in c:\programdata\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\programdata\anaconda3\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: branca>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.18.5)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2020.6.20)
# imports done

# %% [markdown]
# ## 1. Data Collection
# ### - The Communities in Durham

# %%
municipalities = ['Ajax Ontario Canada',
                  'Brock Ontario Canada',
                  'Clarington Ontario Canada',
                  'Oshawa Ontario Canada',
                  'Pickering Ontario Canada',
                  'Scugog Ontario Canada',
                  'Uxbridge Ontario Canada',
                  'Whitby Ontario Canada']

# %% [markdown]
# #### A short function to retreive the latitude and longitude for 1 address

# %%
def get_lat_long(address):
    location = locator.geocode(address)
    if location != None:
        lat = location.latitude
        lon = location.longitude
    else:
        lat = np.nan
        lon = np.nan
    return lat, lon

# %%
# create a locator object
locator = Nominatim(user_agent='myGeocoder')

municipalities_locations = []
for m in municipalities:
    lat, lon = get_lat_long(m)
    municipalities_locations.append([m, lat, lon])
municipalities_locations
# Out:
# [['Ajax Ontario Canada', 43.850374, -79.024658],
#  ['Brock Ontario Canada', 44.347685049999995, -79.10016490761303],
#  ['Clarington Ontario Canada', 43.96868585, -78.65135738273909],
#  ['Oshawa Ontario Canada', 43.91768, -78.862953],
#  ['Pickering Ontario Canada', 43.835765, -79.090576],
#  ['Scugog Ontario Canada', 44.1150554, -78.90598875892695],
#  ['Uxbridge Ontario Canada', 44.1088502, -79.1226768],
#  ['Whitby Ontario Canada', 43.899871, -78.940201]]

# %%
# build a database of venues for all the municipalities
# define foursquare arguments 
client_id ='client id'
client_secret = 'client secret'
version = '20180605'
limit = 100
radius = 10000

#create an empty dataframe
municipalities_venues = pd.DataFrame()

for lst in municipalities_locations:
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        client_id,
        client_secret,
        version,
        lst[1],
        lst[2],
        radius,
        limit)
    results = requests.get(url).json()
    #extract the items
    venues = results['response']['groups'][0]['items']
    #create dataframe
    one_m_venues = json_normalize(venues)
    #add the new dataframe to the collector dataframe
    municipalities_venues = pd.concat([municipalities_venues,one_m_venues], axis=0)

municipalities_venues.shape
# Out:
# (532, 24)

# %% [markdown]
# ### - Extract the Relevant Columns

# %%
print(municipalities_venues.columns)
# Out:
# Index(['referralId', 'reasons.count', 'reasons.items', 'venue.id',
#        'venue.name', 'venue.location.address', 'venue.location.lat',
#        'venue.location.lng', 'venue.location.labeledLatLngs',
#        'venue.location.distance', 'venue.location.postalCode',
#        'venue.location.cc', 'venue.location.city', 'venue.location.state',
#        'venue.location.country', 'venue.location.formattedAddress',
#        'venue.categories', 'venue.photos.count', 'venue.photos.groups',
#        'venue.venuePage.id', 'venue.location.crossStreet',
#        'venue.events.count', 'venue.events.summary',
#        'venue.location.neighborhood'],
#       dtype='object')

# %%
filter_col=['venue.name','venue.location.address','venue.location.city','venue.categories','venue.location.lat','venue.location.lng']
municipalities_venues = municipalities_venues.loc[:,filter_col]
municipalities_venues.head()
# Out:
#                venue.name          venue.location.address venue.location.city  \
# 0  Debbie's Boutique Cafe         94 Harwood Avenue South                Ajax
# 1      Life Time Athletic               100 Beck Crescent                Ajax
# 2            Portly Piper                  235 Bayly St W                Ajax
# 3            Retro Burger                  105 Bayly St W                Ajax
# 4    Maimana Naan & Kabab  279 Kingston Road East, Unit 7                Ajax
#
#                                     venue.categories  venue.location.lat  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...           43.850183
# 1  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...           43.859315
# 2  [{'id': '4bf58dd8d48988d157941735', 'name': 'N...           43.841323
# 3  [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...           43.842269
# 4  [{'id': '503288ae91d4c4b30a586d67', 'name': 'A...           43.863670
#
#    venue.location.lng
# 0          -79.021350
# 1          -79.013105
# 2          -79.026583
# 3          -79.021905
# 4          -79.012364

# %%
municipalities_venues.shape

# %%
#function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list=row['categories']
    except:
        categories_list = row['venue.categories']
    if len(categories_list)==0:
        return None
    else:
        return categories_list[0]['name']

# %%
#unpack the categories
municipalities_venues['venue.categories']=municipalities_venues.apply(get_category_type, axis=1)
municipalities_venues.head()
# Out:
#                venue.name          venue.location.address venue.location.city  \
# 0  Debbie's Boutique Cafe         94 Harwood Avenue South                Ajax
# 1      Life Time Athletic               100 Beck Crescent                Ajax
# 2            Portly Piper                  235 Bayly St W                Ajax
# 3            Retro Burger                  105 Bayly St W                Ajax
# 4    Maimana Naan & Kabab  279 Kingston Road East, Unit 7                Ajax
#
#           venue.categories  venue.location.lat  venue.location.lng
# 0                     Café           43.850183          -79.021350
# 1                      Gym           43.859315          -79.013105
# 2  New American Restaurant           43.841323          -79.026583
# 3             Burger Joint           43.842269          -79.021905
# 4        Afghan Restaurant           43.863670          -79.012364

# %%
#clean the columns
municipalities_venues.columns = [col.split('.')[-1] for col in municipalities_venues.columns]
municipalities_venues.head()
# Out:
#                      name                         address  city  \
# 0  Debbie's Boutique Cafe         94 Harwood Avenue South  Ajax
# 1      Life Time Athletic               100 Beck Crescent  Ajax
# 2            Portly Piper                  235 Bayly St W  Ajax
# 3            Retro Burger                  105 Bayly St W  Ajax
# 4    Maimana Naan & Kabab  279 Kingston Road East, Unit 7  Ajax
#
#                 categories        lat        lng
# 0                     Café  43.850183 -79.021350
# 1                      Gym  43.859315 -79.013105
# 2  New American Restaurant  43.841323 -79.026583
# 3             Burger Joint  43.842269 -79.021905
# 4        Afghan Restaurant  43.863670 -79.012364

# %%
#remove duplicate entries from overlap of radius
municipalities_venues.drop_duplicates(inplace=True)
municipalities_venues.shape
# Out:
# (354, 6)

# %%
#picked up some Toronto locations
indexNames = municipalities_venues[ municipalities_venues['city'] == 'Toronto' ].index
# Delete these row indexes from dataFrame
municipalities_venues.drop(indexNames , inplace=True)
municipalities_venues.shape
# Out:
# (327, 7)

# %%
municipalities_venues
# Out:
#                                name                         address      city  \
# 0            Debbie's Boutique Cafe         94 Harwood Avenue South      Ajax
# 1                Life Time Athletic               100 Beck Crescent      Ajax
# 2                      Portly Piper                  235 Bayly St W      Ajax
# 3                      Retro Burger                  105 Bayly St W      Ajax
# 4              Maimana Naan & Kabab  279 Kingston Road East, Unit 7      Ajax
# ..                              ...                             ...       ...
# 24                            Zehrs                323 Toronto St S  Uxbridge
# 25                          Walmart                    6 Welwood Rd  Uxbridge
# 26                   Uxbridge Arena                   Brock St West  Uxbridge
# 27  Mill Run Golf - Highland Course                             NaN  Uxbridge
# 97             Fionn MacCool's Ajax           36 Kingston Road East      Ajax
#
#                  categories        lat        lng
# 0                      Café  43.850183 -79.021350
# 1                       Gym  43.859315 -79.013105
# 2   New American Restaurant  43.841323 -79.026583
# 3              Burger Joint  43.842269 -79.021905
# 4         Afghan Restaurant  43.863670 -79.012364
# ..                      ...        ...        ...
# 24            Grocery Store  44.089713 -79.130742
# 25         Department Store  44.087675 -79.133171
# 26             Hockey Arena  44.107177 -79.133788
# 27              Golf Course  44.079908 -79.222929
# 97                Irish Pub  43.862393 -79.023159
#
# [327 rows x 6 columns]

# %%
municipalities_venues.reset_index(drop=True, inplace = True)
#municipalities_venues.drop('index',1, inplace = True)
municipalities_venues.head()
# Out:
#                      name                         address  city  \
# 0  Debbie's Boutique Cafe         94 Harwood Avenue South  Ajax
# 1      Life Time Athletic               100 Beck Crescent  Ajax
# 2            Portly Piper                  235 Bayly St W  Ajax
# 3            Retro Burger                  105 Bayly St W  Ajax
# 4    Maimana Naan & Kabab  279 Kingston Road East, Unit 7  Ajax
#
#                 categories        lat        lng
# 0                     Café  43.850183 -79.021350
# 1                      Gym  43.859315 -79.013105
# 2  New American Restaurant  43.841323 -79.026583
# 3             Burger Joint  43.842269 -79.021905
# 4        Afghan Restaurant  43.863670 -79.012364

# %%
cat = municipalities_venues['categories'].unique()
print(len(cat))
cat
# Out:
# 98
# array(['Café', 'Gym', 'New American Restaurant', 'Burger Joint',
#        'Afghan Restaurant', 'Restaurant', 'Bookstore',
#        'Mexican Restaurant', 'Breakfast Spot', 'Coffee Shop', 'Park',
#        'Sports Bar', 'Garden Center', 'Gym / Fitness Center',
#        'Grocery Store', 'Japanese Restaurant', 'Liquor Store',
#        'Wings Joint', 'Warehouse Store', 'Brewery',
#        'Middle Eastern Restaurant', 'Indian Restaurant', 'Ice Cream Shop',
#        'Diner', 'Pizza Place', 'Fast Food Restaurant', 'Smoothie Shop',
#        'Dessert Shop', 'American Restaurant', 'Pet Store',
#        'Athletics & Sports', 'Movie Theater', 'Food',
#        'Furniture / Home Store', 'Gastropub', 'Golf Course',
#        'Chinese Restaurant', 'Bakery', 'Pharmacy', 'Seafood Restaurant',
#        'BBQ Joint', 'Discount Store', 'Big Box Store', 'Pub',
#        'Music Store', 'Bank', 'Soccer Stadium', 'Italian Restaurant',
#        'Cosmetics Shop', 'Food Truck', 'Sandwich Place', 'Supermarket',
#        'Lake', 'Gas Station', 'Resort', 'Hardware Store', 'Racetrack',
#        'Market', 'Beer Store', 'Farmers Market', 'Sushi Restaurant',
#        'Ski Area', 'Pool', 'Zoo', 'Department Store', 'Burrito Place',
#        'Paper / Office Supplies Store', 'Intersection', 'Stadium',
#        'Harbor / Marina', 'Smoke Shop', 'Theater', 'Deli / Bodega',
#        'Art Gallery', 'Hockey Arena', 'Museum', 'Gym Pool', 'Arcade',
#        'Asian Restaurant', 'Hotel', 'Dog Run', 'Scenic Lookout', 'Farm',
#        'Bar', 'Recreation Center', 'Baseball Field', 'Flea Market',
#        'Campground', 'Electronics Store', 'Beach', 'Thai Restaurant',
#        'Zoo Exhibit', 'Vietnamese Restaurant', 'Fried Chicken Joint',
#        'Convenience Store', 'Casino', 'Trail', 'Irish Pub'], dtype=object)

# %% [markdown]
# ### Get the Categories Museum, Art Gallery, and Theater

# %%
museums = municipalities_venues.loc[municipalities_venues['categories']=='Museum']
museums
# Out:
#                         name                address    city categories  \
# 182  Oshawa Community Museum  1450 Simcoe St. South  Oshawa     Museum
#
#            lat        lng
# 182  43.863789 -78.827205

# %%
arts = municipalities_venues.loc[municipalities_venues['categories']=='Art Gallery']
arts
# Out:
#                                         name            address    city  \
# 174  The Robert McLaughlin Gallery (@theRMG)        72 Queen St  Oshawa
# 231                          Station Gallery  1450 Henry Street  Whitby
#
#       categories        lat        lng
# 174  Art Gallery  43.895015 -78.865704
# 231  Art Gallery  43.860443 -78.935325

# %%
theaters = municipalities_venues.loc[municipalities_venues['categories']=='Theater']
theaters
# Out:
#                       name          address    city categories        lat  \
# 162  Oshawa Little Theatre  62 Russett Ave.  Oshawa    Theater  43.930277
#
#            lng
# 162 -78.880503

# %%
arts_df = pd.concat([museums, arts, theaters], axis=0)
arts_df
# Out:
#                                         name                address    city  \
# 182                  Oshawa Community Museum  1450 Simcoe St. South  Oshawa
# 174  The Robert McLaughlin Gallery (@theRMG)            72 Queen St  Oshawa
# 231                          Station Gallery      1450 Henry Street  Whitby
# 162                    Oshawa Little Theatre        62 Russett Ave.  Oshawa
#
#       categories        lat        lng
# 182       Museum  43.863789 -78.827205
# 174  Art Gallery  43.895015 -78.865704
# 231  Art Gallery  43.860443 -78.935325
# 162      Theater  43.930277 -78.880503

# %% [markdown]
# ## More Venues Needed
# #### With only four venues from Foursquare a web search for more was done.  This resulted in a total of 32 venues which were stored in a CSV file.

# %%
# reading in the csv file

import csv

arts_df = pd.read_csv('Durham Data.csv')
arts_df.head()
# Out:
#                      name              address        city   categories  \
# 0      Blue Willow Studio   19 Patricia Avenue      Oshawa  Art Gallery
# 1         Gallery 282 Ltd  321 Northcliffe Ave      Oshawa  Art Gallery
# 2    Images 21 Art Studio    552 Westney Rd. N        Ajax  Art Gallery
# 3  Magic Door Art Gallery     100 River Street  Sunderland  Art Gallery
# 4     Marc Barrie Gallery           1613 7 Hwy    Brougham  Art Gallery
#
#          lat        lng           Phone
# 0  43.901553 -78.849534    905 435-0575
# 1        NaN        NaN    905 576-2187
# 2        NaN        NaN  (905) 239-6363
# 3        NaN        NaN  (705) 357-1973
# 4        NaN        NaN  (905) 683-7010

# %%
#change the data types of the lat and lng columnss to float
arts_df[['lat','lng']] = arts_df[['lat','lng']].apply(pd.to_numeric)
arts_df.dtypes
# Out:
# name           object
# address        object
# city           object
# categories     object
# lat           float64
# lng           float64
# Phone          object
# dtype: object

# %%
# find the latitude and longitude for each row in the arts_df

adds = arts_df['address'].to_list()
cities = arts_df['city'].to_list()
t_adds = [m+' '+n for m,n in zip(adds, cities)]
lat_lst =[]
long_lst = []
for ad in t_adds:
    #print(ad)
    lat, lng = get_lat_long(ad)
    #print(lat, lng)
    lat_lst.append(lat)
    long_lst.append(lng)


arts_df['lat']= lat_lst
arts_df['lng']= long_lst
arts_df.head()
# Out:
#                      name              address        city   categories  \
# 0      Blue Willow Studio   19 Patricia Avenue      Oshawa  Art Gallery
# 1         Gallery 282 Ltd  321 Northcliffe Ave      Oshawa  Art Gallery
# 2    Images 21 Art Studio    552 Westney Rd. N        Ajax  Art Gallery
# 3  Magic Door Art Gallery     100 River Street  Sunderland  Art Gallery
# 4     Marc Barrie Gallery           1613 7 Hwy    Brougham  Art Gallery
#
#          lat        lng           Phone
# 0  43.901553 -78.849534    905 435-0575
# 1  43.917164 -78.884608    905 576-2187
# 2  43.868353 -79.039990  (905) 239-6363
# 3  54.875990  -1.421068  (705) 357-1973
# 4  54.648120  -2.729612  (905) 683-7010

# %%
#remove any NaN entries
arts_df.dropna(subset = ['lat','lng'], inplace = True)
arts_df
# Out:
#                                                  name  \
# 0                                  Blue Willow Studio
# 1                                     Gallery 282 Ltd
# 2                                Images 21 Art Studio
# 3                              Magic Door Art Gallery
# 4                                 Marc Barrie Gallery
# 6                                     Preston Gallery
# 7                                  Ronden Art Gallery
# 8                 The LivingRoom Community Art Studio
# 10                The Robert McLaughlin Gallery (RMG)
# 11                   Visual Arts Centre of Clarington
# 12                                    Station Gallery
# 13                                 Bowmanville Museum
# 14  Cannington Historical Society's Centennial Museum
# 15                      Clarington Museums & Archives
# 17          Lynde House Museum & Warren General Store
# 18                          Ontario Golf Hall of Fame
# 19              Oshawa Military and Industrial Museum
# 20                         Oshawa Sports Hall of Fame
# 21                           Pickering Museum Village
# 22                             Ajax Community Theatre
# 23                        The Driftwood Theatre Group
# 24                          Whitby Courthouse Theatre
# 25                                   Yuk Yuk's Durham
# 26                       Durham Shoestring Performers
# 27                              Oshawa Little Theatre
# 28                        Regent Theatre Ontario Tech
# 29                                     Oshawa  Museum
# 30                              Oshawa Little Theater
# 31                                    Parkwood Estate
#
#                       address         city   categories        lat        lng  \
# 0          19 Patricia Avenue       Oshawa  Art Gallery  43.901553 -78.849534
# 1         321 Northcliffe Ave       Oshawa  Art Gallery  43.917164 -78.884608
# 2           552 Westney Rd. N         Ajax  Art Gallery  43.868353 -79.039990
# 3            100 River Street   Sunderland  Art Gallery  54.875990  -1.421068
# 4                  1613 7 Hwy     Brougham  Art Gallery  54.648120  -2.729612
# 6            77 Brock St West     Uxbridge  Art Gallery  44.108679 -79.123945
# 7       133 Taunton Road West       Oshawa  Art Gallery  43.931302 -78.884629
# 8     149 Simcoe Street South       Oshawa  Art Gallery  43.893687 -78.861618
# 10            72 Queen Street       Oshawa  Art Gallery  43.895721 -78.866684
# 11         143 Simpson Avenue  Bowmanville  Art Gallery  43.903348 -78.671832
# 12          1450 Henry Street       Whitby  Art Gallery  43.861444 -78.939736
# 13               37 Silver St  Bowmanville       Museum  43.914519 -78.689805
# 14            72 Peace Street   Cannington       Museum  44.349093 -79.034919
# 15           62 Temperance St  Bowmanville       Museum  43.913990 -78.688769
# 17     900 Brock Street South       Whitby       Museum  43.871501 -78.938801
# 18          40 Elgin Park Dr.     Uxbridge       Museum  44.097203 -79.117777
# 19  1000 Stevenson Road North       Oshawa       Museum  43.916695 -78.893955
# 20              99 Athol St E       Oshawa       Museum  43.897022 -78.859198
# 21    2365 6th Concession Rd.    Greenwood       Museum  43.927077 -79.072103
# 22     78 Church Street South         Ajax      Theater  43.845407 -79.051519
# 23           910 Walnut Court       Oshawa      Theater  43.897956 -78.828491
# 24    416 Centre Street South       Whitby      Theater  43.875286 -78.943060
# 25           235 Bayly St. W.         Ajax      Theater  43.841229 -79.026484
# 26                45 Queen St       Oshawa      Theater  43.895721 -78.866684
# 27             62 Russett Ave       Oshawa      Theater  43.929684 -78.882576
# 28               50 King St E       Oshawa      Theater  43.902832 -78.840904
# 29      1450 Simcoe St. South       Oshawa       Museum  43.865427 -78.828968
# 30            62 Russett Ave.       Oshawa      Theater  43.929684 -78.882576
# 31       270 Simcoe St. North       Oshawa       Museum  43.904216 -78.867904
#
#                     Phone
# 0            905 435-0575
# 1            905 576-2187
# 2          (905) 239-6363
# 3          (705) 357-1973
# 4          (905) 683-7010
# 6            905-550-8825
# 7            905 718 9099
# 8                    none
# 10         (905) 576-3000
# 11         (905) 623-5831
# 12         (905) 668-4185
# 13         (905) 623-2734
# 14           705 432 3136
# 15         (905) 623-2734
# 17         (905) 665-3131
# 18         (905) 852-4379
# 19         (905) 728-6199
# 20         (905) 245-0360
# 21         (905) 683-8401
# 22         (289) 892-4132
# 23         (905) 576-2396
# 24         (905) 668-8111
# 25         (416) 967-6425
# 26         (905) 725-9256
# 27         (905) 723-0282
# 28  (905) 721-3399 ext. 2
# 29         (905) 436-7624
# 30         (905) 723 0282
# 31         (905) 433 4311

# %%
# save the dataframe to a csv file so it can be used in future codes

arts_df.to_csv('arts_venues_data.csv')
print('done')
# Out:
# done

# %% [markdown]
# # 2. Creating the Map

# %%
#find a central point for Durham
locator=Nominatim(user_agent='dh_explorer')
Durham_location = locator.geocode('Durham,Ontario,Canada')
Durham_location
# Out:
# Location(Durham, Oshawa, Durham Region, Golden Horseshoe, Ontario, Canada, (44.0338942, -78.86978798748362, 0.0))

# %%
D_lat = Durham_location.latitude
D_lon= Durham_location.longitude
print(D_lat, D_lon)
# Out:
# 44.0338942 -78.86978798748362

# %%
# create map of Durham 
map_durham = folium.Map(location=[D_lat, D_lon], 
                        zoom_start =9,
                       )

# %%
# add legend from picture file
from folium.plugins import FloatImage
image_file = 'legend.PNG'

FloatImage(image_file, bottom=75, left=80).add_to(map_durham)

# %%
#add a title
loc = 'Durham Art and Culture Venues'
title_html = '''
             <h3 align="center" style="font-size:18px"><b>{}</b></h3>
             '''.format(loc)   

map_durham.get_root().html.add_child(folium.Element(title_html))

# %%
# add markers
for lat, lng, name, address, cat, city, phone in zip(arts_df['lat'], 
                                                     arts_df['lng'],
                                                     arts_df['name'],
                                                     arts_df['address'],
                                                     arts_df['categories'],
                                                     arts_df['city'],
                                                     arts_df['Phone']):
    
    #create the text for the popup labels
    if phone == 'none': #there is no phone number
        lab='''{},<br>
        {}, {}'''.format(name, address, city)
        
    else: #there is a phone number
        lab='''{},<br>
        {}, {}<br>
        {}'''.format(name, address, city, phone)
    
    iframe = folium.IFrame(lab,
                       width=150,
                       height=150)
    
    popup = folium.Popup(iframe,
                     max_width=200)
    
    #select the colours for the icons
    if cat == 'Art Gallery':
        colour = 'blue'
    elif cat == 'Museum':
        colour = 'red'
    else: #only Theater left
        colour = 'green'
   
    #create and add each marker
    folium.Marker(
        [lat, lng],
        radius = 5,
        popup = popup,
        icon=folium.Icon(color=colour,icon = 'fa-asterisk', prefix ='fa'),
        parse_html = False).add_to(map_durham)

map_durham
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Above map may not show the legend in the npviewer

# %% [markdown]
# ### Convert map to HTML file

# %%
map_durham.save(outfile = 'Durham map.html')
print('done')
# Out:
# done
